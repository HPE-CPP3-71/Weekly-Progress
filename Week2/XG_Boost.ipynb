# %% [markdown]
# # **DATASETS**

# %%
import pandas as pd

# --- Load Monday's dataset ---
ds_mon = pd.read_csv('/content/Monday-WorkingHours.pcap_ISCX.csv')
print("\n--- Monday's Dataset (ds_mon) ---")
print("Head:")
display(ds_mon.head())
print(f"Dimensions: {ds_mon.shape}")
# 1. Get the number of different (unique) values
unique_count = ds_mon[' Label'].nunique()
print(f"Number of unique values: {unique_count}")
# 2. Get the count of how many times each value appears
value_distribution = ds_mon[' Label'].value_counts()
print("\nFrequency of each value:")
print(value_distribution)
# Out:
# --- Monday's Dataset (ds_mon) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %%
# --- Load Wednesday's dataset ---
ds_wed = pd.read_csv('/content/Wednesday-workingHours.pcap_ISCX.csv')
print("\n--- Wednesday's Dataset (ds_wed) ---")
print("Head:")
display(ds_wed.head())
print(f"Dimensions: {ds_wed.shape}")
# 1. Get the number of different (unique) values
unique_count = ds_wed[' Label'].nunique()
print(f"Number of unique values: {unique_count}")

# 2. Get the count of how many times each value appears
value_distribution = ds_wed[' Label'].value_counts()
print("\nFrequency of each value:")
print(value_distribution)
# Out:
# --- Wednesday's Dataset (ds_wed) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# ...

# %% [markdown]
# For Thursday and Friday, there are multiple files. I will concatenate them into single dataframes named `ds_thu` and `ds_fri` respectively. Please note that there was no specific 'Tuesday-WorkingHours' file found, so `ds_tue` will not be created.

# %%
# --- Load and concatenate Thursday's datasets ---
thur_files = [
    '/content/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',
    '/content/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv'
]

ds_thu = pd.concat([pd.read_csv(f) for f in thur_files], ignore_index=True)
print("\n--- Thursday's Dataset (ds_thu) ---")
print("Head:")
display(ds_thu.head())
print(f"Dimensions: {ds_thu.shape}")
unique_count = ds_thu[' Label'].nunique()
print(f"Number of unique values: {unique_count}")

# 2. Get the count of how many times each value appears
value_distribution = ds_thu[' Label'].value_counts()
print("\nFrequency of each value:")
print(value_distribution)
# Out:
# --- Thursday's Dataset (ds_thu) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22             166                   1
# 1              60148              83                   1
# 2                123           99947                   1
# 3                123           37017                   1
# 4                  0       111161336                 147
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            0
# 1                        2                            0
# 2                        1                           48
# 3                        1                           48
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       0
# 1                             0                       0
# 2                            48                      48
# ...

# %%
# --- Load and concatenate Friday's datasets ---
fri_files = [
    '/content/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',
    '/content/Friday-WorkingHours-Morning.pcap_ISCX.csv',
    '/content/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv'
]

ds_fri = pd.concat([pd.read_csv(f) for f in fri_files], ignore_index=True)
print("\n--- Friday's Dataset (ds_fri) ---")
print("Head:")
display(ds_fri.head())
print(f"Dimensions: {ds_fri.shape}")
unique_count = ds_fri[' Label'].nunique()
print(f"Number of unique values: {unique_count}")

# 2. Get the count of how many times each value appears
value_distribution = ds_fri[' Label'].value_counts()
print("\nFrequency of each value:")
print(value_distribution)
# Out:
# --- Friday's Dataset (ds_fri) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %%
# Merge all datasets into a single DataFrame 'df'
df = pd.concat([ds_mon, ds_wed, ds_thu, ds_fri], ignore_index=True)

print("\n--- Merged Dataset (df) ---")
print("Head:")
display(df.head())
print(f"Dimensions: {df.shape}")
# Out:
# --- Merged Dataset (df) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %% [markdown]
# ## Import Libraries
#
# First, let's make sure all necessary libraries are imported, including `sklearn` components for preprocessing, model training, and evaluation, as well as `imblearn` for oversampling.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from imblearn.over_sampling import SMOTE

# %%
if ' Label' in df.columns:
    df.rename(columns={' Label': 'Label'}, inplace=True)
    print("Column ' Label' renamed to 'Label'.")
else:
    print("Column ' Label' not found.")

display(df.head())
# Out:
# Column ' Label' renamed to 'Label'.
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %%
df.Label.value_counts()
# Out:
# Label
# BENIGN                        1841023
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
# Map specific DoS attacks to a general 'DoS' label
dos_attacks = [
    'DoS Hulk',
    'DoS slowloris',
    'DoS GoldenEye',
    'DoS Slowhttptest',
    'DDoS'
]

df['Label'] = df['Label'].replace(dos_attacks, 'DoS')

print("Label value counts after unifying DoS attacks:")
display(df['Label'].value_counts())
# Out:
# Label value counts after unifying DoS attacks:
# Label
# BENIGN                        1841023
# DoS                            380688
# PortScan                       158930
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
# Randomly sample instances from majority classes and group specific attack types

# Minor classes to keep entirely (or with specific small fractions if desired)
df_minor = df[df['Label'].isin([
    'Bot',
    'Infiltration',
    'Web Attack Â  XSS',
    'Web Attack Â  Sql Injection',
    'Heartbleed'
])]

# BENIGN class with 1% sampling
df_BENIGN = df[df['Label'] == 'BENIGN'].sample(frac=0.01,replace=False, weights=None, random_state=None)

# DoS-related classes with 5% sampling
df_DoS = df[df['Label'].isin([
    'DoS'
])].sample(frac=0.05,replace=False, weights=None, random_state=None)

# PortScan class with 5% sampling
df_PortScan = df[df['Label'] == 'PortScan'].sample(frac=0.05,replace=False, weights=None, random_state=None)

# Web Attack Brute Force class with 20% sampling
df_BruteForce = df[df['Label'] == 'Web Attack Â  Brute Force'].sample(frac=0.2,replace=False, weights=None, random_state=None)

# %%
# Concatenate all sampled dataframes into a single DataFrame 'df_s' without ** df_DDoS **
df_s = pd.concat([df_BENIGN, df_DoS, df_PortScan, df_BruteForce, df_minor], ignore_index=True)

print("--- Sampled Dataset (df_s) ---")
print("Head:")
display(df_s.head())
print(f"Dimensions: {df_s.shape}")
print("Frequency of each value in df_s:")
display(df_s['Label'].value_counts())
# Out:
# --- Sampled Dataset (df_s) ---
# Head:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              58504              51                   1
# 1                443        71108562                  57
# 2                 53           90977                   2
# 3              33910              63                   1
# 4                443          176756                   7
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                       79                         5381
# 2                        2                           64
# 3                        1                            0
# 4                        5                          376
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                         14711                    1093
# 2                           198                      32
# ...

# %%
df_s = df_s.sort_index()

# %%
import os
# Define the directory path
output_dir = './content/'
# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)
# Save the sampled dataset
df_s.to_csv(os.path.join(output_dir, 'CICIDS2017_sample_GROUP_DoS.csv'), index=0)

# %% [markdown]
# # **Preprocessing (normalization and padding values)**

# %%
df = pd.read_csv('/content/content/CICIDS2017_sample_GROUP_DoS.csv')

# %%
df.Label.value_counts()
# Out:
# Label
# DoS             19034
# BENIGN          18410
# PortScan         7946
# Bot              1966
# Infiltration       36
# Heartbleed         11
# Name: count, dtype: int64

# %%
# Min-max normalization
numeric_features = df.dtypes[df.dtypes != 'object'].index
df[numeric_features] = df[numeric_features].apply(
    lambda x: (x - x.min()) / (x.max()-x.min()))
# Fill empty values by 0
df = df.fillna(0)

# %% [markdown]
# # **split train set and test set**

# %%
# Create a temporary DataFrame to work on, dropping rows with NaN in 'Label'
df_temp = df.copy()
df_temp.dropna(subset=['Label'], inplace=True)

labelencoder = LabelEncoder()
df_temp['Label'] = labelencoder.fit_transform(df_temp['Label'])

X = df_temp.drop(['Label'],axis=1).values
y = df_temp['Label'].values
# Ensure y is explicitly integer type for SMOTE compatibility
y = y.astype(int)

X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8, test_size = 0.2, random_state = 0,stratify = y)

# %%
X_train.shape
pd.Series(y_train).value_counts()
# Out:
# 2    15227
# 0    14728
# 5     6356
# 1     1573
# 4       29
# 3        9
# Name: count, dtype: int64

# %% [markdown]
# # **Oversampling by SMOTE**

# %%
# Determine sampling strategy for SMOTE dynamically
# We want to oversample all minority classes to be at least 1500 samples or more if they are already larger.
# The majority class (usually 'BENIGN') will not be oversampled.

# Get current class distribution
class_counts = pd.Series(y_train).value_counts()

# Identify minority classes (excluding the largest class, which we assume is benign/majority)
majority_class_label = class_counts.idxmax()
majority_class_count = class_counts.max()

sampling_strategy = {}
for label, count in class_counts.items():
    # Only oversample classes if their current count is less than the target (e.g., 1500)
    # And ensure the target is at least the current count if we want to oversample it.
    # For this strategy, let's target 1500 as a baseline, but not go beyond majority count.
    if count < 1500 and label != majority_class_label: # Only consider classes truly needing oversampling
        sampling_strategy[label] = min(1500, majority_class_count)
    elif count >= 1500 and label != majority_class_label: # If a minority class already has more than 1500, oversample it to its current level or higher if aiming for balance.
        # This ensures we don't undersample, for example, oversample to the majority class count for better balance
        sampling_strategy[label] = majority_class_count

# Filter out classes that don't need oversampling based on the current context
sampling_strategy = {k: v for k, v in sampling_strategy.items() if v > class_counts[k]}

smote = SMOTE(sampling_strategy=sampling_strategy, random_state=42) # Set random_state for reproducibility
X_train, y_train = smote.fit_resample(X_train, y_train)

print("X_train shape after SMOTE:", X_train.shape)
print("y_train value counts after SMOTE:")
print(pd.Series(y_train).value_counts())
# Out:
# X_train shape after SMOTE: (63908, 78)
# y_train value counts after SMOTE:
# 5    15227
# 0    15227
# 2    15227
# 1    15227
# 4     1500
# 3     1500
# Name: count, dtype: int64

# %%
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
pd.Series(y_train).value_counts()
# Out:
# 5    15227
# 0    15227
# 2    15227
# 1    15227
# 4     1500
# 3     1500
# Name: count, dtype: int64

# %% [markdown]
# # **Machine learning model training**

# %%
# XGboost training and prediction
xg = xgb.XGBClassifier(n_estimators = 10)
xg.fit(X_train,y_train)
xg_score=xg.score(X_test,y_test)
y_predict=xg.predict(X_test)
y_true=y_test
print('Accuracy of XGBoost: '+ str(xg_score))
precision,recall,fscore,none= precision_recall_fscore_support(y_true, y_predict, average='weighted')
print('Precision of XGBoost: '+(str(precision)))
print('Recall of XGBoost: '+(str(recall)))
print('F1-score of XGBoost: '+(str(fscore)))
print(classification_report(y_true,y_predict))
cm=confusion_matrix(y_true,y_predict)
f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Accuracy of XGBoost: 0.9928277607847273
# Precision of XGBoost: 0.9931118310554989
# Recall of XGBoost: 0.9928277607847273
# F1-score of XGBoost: 0.9928727208378718
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      3682
#            1       0.92      1.00      0.96       393
#            2       0.99      1.00      1.00      3807
#            3       1.00      1.00      1.00         2
#            4       0.83      0.71      0.77         7
#            5       1.00      1.00      1.00      1590
#
#     accuracy                           0.99      9481
#    macro avg       0.96      0.95      0.95      9481
# weighted avg       0.99      0.99      0.99      9481

# %%
xg_train=xg.predict(X_train)
xg_test=xg.predict(X_test)

# %% [markdown]
# # **Feature Selection**

# %%
xgb_feature = xg.feature_importances_

# %%
feature=(df.drop(['Label'],axis=1)).columns.values
print ("Features sorted by their score:")
print (sorted(zip(map(lambda x: round(x, 4), xgb_feature), feature), reverse=True))
# Out:
# Features sorted by their score:
# ...

# %%
f_list = sorted(zip(map(lambda x: round(x, 4), xgb_feature), feature), reverse=True)

# %%
len(f_list)
# Out:
# 78

# %%
# Select the important features from top-importance to bottom-importance until the accumulated importance reaches 0.9 (out of 1)
Sum = 0
fs = []
for i in range(0, len(f_list)):
    Sum = Sum + f_list[i][0]
    fs.append(f_list[i][1])
    if Sum>=0.9:
        break

# %%
X_fs = df[fs].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X_fs,y, train_size = 0.8, test_size = 0.2, random_state = 0,stratify = y)

# %%
X_train.shape
# Out:
# (37922, 18)

# %%
pd.Series(y_train).value_counts()
# Out:
# 2    15227
# 0    14728
# 5     6356
# 1     1573
# 4       29
# 3        9
# Name: count, dtype: int64

# %% [markdown]
# # **Machine learning model training after feature selection**

# %%
xg = xgb.XGBClassifier(n_estimators = 10)
xg.fit(X_train,y_train)
xg_score=xg.score(X_test,y_test)
y_predict=xg.predict(X_test)
y_true=y_test
print('Accuracy of XGBoost: '+ str(xg_score))
precision,recall,fscore,none= precision_recall_fscore_support(y_true, y_predict, average='weighted')
print('Precision of XGBoost: '+(str(precision)))
print('Recall of XGBoost: '+(str(recall)))
print('F1-score of XGBoost: '+(str(fscore)))
print(classification_report(y_true,y_predict))
cm=confusion_matrix(y_true,y_predict)
f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Accuracy of XGBoost: 0.9943043982702247
# Precision of XGBoost: 0.9944107705894938
# Recall of XGBoost: 0.9943043982702247
# F1-score of XGBoost: 0.9943005222778586
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      3682
#            1       0.94      0.99      0.96       393
#            2       1.00      1.00      1.00      3807
#            3       1.00      1.00      1.00         2
#            4       0.80      0.57      0.67         7
#            5       1.00      1.00      1.00      1590
#
#     accuracy                           0.99      9481
#    macro avg       0.95      0.93      0.94      9481
# weighted avg       0.99      0.99      0.99      9481

# %%
xg_train=xg.predict(X_train)
xg_test=xg.predict(X_test)
